# %% [markdown]
# <a href="https://colab.research.google.com/github/tustus1022-ui/esaa/blob/main/YB_0515_%EC%97%B0%EC%8A%B5%EB%AC%B8%EC%A0%9C_%ED%9A%8C%EA%B7%802.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **1. 규제 선형 회귀 모델/ 회귀 트리**
# - 릿지 회귀모델 및 회귀 트리를 이용하여 전복의 나이를 예측해 보세요.
#
# - 전복의 ‘성별’, ‘키’, ‘지름’, ‘높이’, ‘전체무게’, ‘몸통무게’, ‘내장무게’, ‘껍질무게’를 이용해 ‘껍질의 고리수’를 예측한 뒤, **예측된 ‘껍질의 고리수’에 1.5를 더하면 전복의 나이**가 됩니다.

# %%
# 기본 모듈 불러오기
import numpy as np
import pandas as pd

import warnings
warnings.filterwarnings(action='ignore')

# %% [markdown]
# ### 1) 데이터 불러오기 및 데이터 선택

# %%
# 데이터 로드
data = pd.read_csv("./abalone.csv")

# 성별 M은 Male, F는 Female, I는 Infant 이므로 따로 열 만들기
for label in "MFI":
    data[label] = data["Sex"] == label
data.drop('Sex', axis=1, inplace=True)

# X,y 데이터 선택
y = data.Rings.values
data.drop('Rings', axis=1, inplace=True)

X = data.values.astype(float)

# %% [markdown]
# ## 2) train/test 분리
# : 테스트 셋과 데이터 셋을 7:3 비율로 분리하세요.

# %%
# 필요한 모듈 불러오기
from sklearn.model_selection import train_test_split

# %%
# train과 test set 분리 (train:test = 7:3 비율로)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=100)

# %% [markdown]
# ## 3) 릿지 모델을 이용한 모델링
# : 릿지 모델을 이용하여 전복의 나이를 예측해 보고 결과를 평가해 보세요.

# %% [markdown]
#  3-1) 릿지모델 생성, 교차검증, 평가에 필요한 모듈을 불러오세요.

# %%
#필요한 모듈 불러오기
from sklearn.linear_model import Ridge
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error

# %% [markdown]
# 3-2) 릿지 모델을 생성하고 훈련하여 MSE와 RMSE를 구하세요. 릿지 모델 생성 시  alpha는 0.3으로 설정합니다. (교차 검증 하지 않습니다.)

# %%
#릿지모델 생성 및 훈련
ridge=Ridge(alpha=0.3)
ridge.fit(X_train, y_train)

#예측값 구하기
y_preds=ridge.predict(X_test)

#구한 예측값을 활용해 최종적으로 전복의 나이 예측
y_age = y_preds + 1.5

#MSE와 RMSE구하기
mse = mean_squared_error(y_test, y_preds)
rmse = np.sqrt(mse)

print(f"MSE : {mse:.3f}")
print(f"RMSE : {rmse:.3f}")
# Out:
# MSE : 4.928
# RMSE : 2.220

# %% [markdown]
# 3-3) 릿지 모델에서 회귀 계수 값을 구해 알 수 있는 점을 작성하시오. (각 컬럼의 정보는 data.colums 참고)

# %%
data.columns
# Out:
# Index(['Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight',
#        'Viscera weight', 'Shell weight', 'M', 'F', 'I'],
#       dtype='object')

# %%
ridge.coef_
# Out:
# array([  2.71124367,   7.4908266 ,   6.45062639,   8.6883876 ,
#        -19.9701431 ,  -8.49388705,   9.20479029,   0.28579361,
#          0.29680064,  -0.58259425])

# %% [markdown]
# - Shucked weight, Viscera weight 가 증가하면 전복의 나이가 크게 감소함을 알 수 있으며, 성별이 남성인 것(M)과 Height, Whole weight는 증가함에 따라 전복의 나이가 증가함을 알 수 있다.

# %% [markdown]
# 3-3) 교차검증을 이용하여 0, 0.1, 1, 10, 100 중  모델 성능이 가장 좋게 나오는 (rmse가 최소가 되는) alpha를 구하세요.

# %%
# 주어진 alpha
alphas=[0, 0.1, 1, 10, 100]

# %%
#alphas list 값을 반복하면서 alpha에 따른 평균 rmse를 구함
for alpha in alphas:
  ridge=Ridge(alpha=alpha)

  #cross_val_score를 이용해 5 폴드의 평균 RMSE를 계산
  neg_mse_scores=cross_val_score(ridge, X_train, y_train, scoring="neg_mean_squared_error", cv=5)
  rmse_scores=np.sqrt(-1*neg_mse_scores)
  avg_rmse=np.mean(rmse_scores)
  print( 'alpha {0} 일 때 5 folds의 평균 RMSE: {1:.3f}'. format(alpha, avg_rmse))
# Out:
# alpha 0 일 때 5 folds의 평균 RMSE: 2.201
# alpha 0.1 일 때 5 folds의 평균 RMSE: 2.199
# alpha 1 일 때 5 folds의 평균 RMSE: 2.204
# alpha 10 일 때 5 folds의 평균 RMSE: 2.348
# alpha 100 일 때 5 folds의 평균 RMSE: 2.614

# %% [markdown]
# ## 4) XGBRegressor을 이용한 모델링
# : XGBRegressor 모델을 이용하여 전복의 나이를 예측해 보고 결과를 평가해 보세요.

# %% [markdown]
# 4-1) XGBRegressor 훈련, 평가에 필요한 모듈을 불러오세요.

# %%
# 필요한 모듈 임포트
from xgboost import XGBRegressor

# %% [markdown]
# 4-2) XGBregressor 모델을 생성하고 훈련하여 MSE와 RMSE를 구하세요.

# %%
#모델 생성 및 훈련
xgb_reg=XGBRegressor(n_estimators=100)
xgb_reg.fit(X_train, y_train)

#예측값 구하기
y_preds=xgb_reg.predict(X_test)

#구한 예측값을 활용해 최종적으로 전복의 나이 예측
y_age = y_preds + 1.5

#MSE와 RMSE 구하기
mse = mean_squared_error(y_test, y_preds)
rmse = np.sqrt(mse)

print(f"MSE : {mse:.3f}")
print(f"RMSE : {rmse:.3f}")
# Out:
# MSE : 5.480
# RMSE : 2.341

# %% [markdown]
# 4-3) 생성한 모델의 피처 중요도를 시각화해보세요.

# %%
import seaborn as sns
# %matplotlib inline

feature_series=pd.Series(data=xgb_reg.feature_importances_, index=data.columns)
feature_series=feature_series.sort_values(ascending=False)
sns.barplot(x=feature_series, y=feature_series.index)
# Out:
# <Axes: xlabel='None', ylabel='None'>

# %% [markdown]
# ---

# %% [markdown]
# # **2. 로지스틱 회귀분석**
# load_wine() 함수를 이용하여 와인 데이터를 다항분류하는 로지스틱 회귀모델을 생성하세요.

# %%
# 필요한 모듈 불러오기
from sklearn.datasets import load_wine
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

# %% [markdown]
# ## 1) 데이터 불러오기 및 변수 선택

# %%
wine = load_wine()

wine_x = wine.data # x변수
wine_y = wine.target # y변수

# %% [markdown]
# ## 2) train/test 셋 분리

# %%
x_train, x_test, y_train, y_test = train_test_split(wine_x, wine_y, test_size=0.3, random_state=123)

x_train.shape
y_train.shape
# Out:
# (124,)

# %% [markdown]
# ## 3) 로지스틱 회귀모델을 이용한 모델링 (발표)

# %% [markdown]
# 3-1) 로지스틱 회귀모델을 생성하여 훈련하세요.

# %%
model = LogisticRegression(multi_class='multinomial')
model.fit(X = x_train, y=y_train)
# Out:
# LogisticRegression(multi_class='multinomial')

# %% [markdown]
# 3-2) 회귀 모델의 기울기와 절편을 구하세요.

# %%
#기울기
model.coef_
# Out:
# array([[-1.99751338e-01,  3.65451144e-01,  1.49472353e-01,
#         -1.88027194e-01, -2.28494592e-02,  1.95456785e-01,
#          4.66701970e-01, -1.66796877e-02,  8.23898405e-02,
#          6.75013134e-02, -1.92622072e-02,  2.94916201e-01,
#          7.42522347e-03],
#        [ 5.96476523e-01, -7.88673910e-01, -1.26181652e-01,
#          2.12254429e-01, -1.13504086e-02,  3.15786394e-01,
#          3.55148523e-01,  3.34675938e-02,  2.79036084e-01,
#         -1.17202662e+00,  2.61166065e-01,  4.64732238e-01,
#         -8.33633769e-03],
#        [-3.96725185e-01,  4.23222765e-01, -2.32907005e-02,
#         -2.42272356e-02,  3.41998678e-02, -5.11243179e-01,
#         -8.21850494e-01, -1.67879061e-02, -3.61425924e-01,
#          1.10452531e+00, -2.41903857e-01, -7.59648438e-01,
#          9.11114220e-04]])

# %%
#절편
model.intercept_
# Out:
# array([-0.04177842,  0.09551058, -0.05373216])

# %% [markdown]
# 3-3) 모델의 정확도를 구하세요.

# %%
#모델의 예측값 구하기
y_pred = model.predict(x_test)

#모델의 정확도 구하기
acc = metrics.accuracy_score(y_test, y_pred)
print(acc)
# Out:
# 0.9629629629629629
